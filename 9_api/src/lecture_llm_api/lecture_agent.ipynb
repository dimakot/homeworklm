# %%
from agno.agent import Agent
from agno.db.sqlite import SqliteDb
from agno.models.openai import OpenAIChat
from agno.os import AgentOS
from agno.tools.mcp import MCPTools

# ************* Create Agent *************
agno_agent = Agent(
    name="Agno Agent",
    model=OpenAIChat(id="claude-sonnet-4-5"),
    # Add a database to the Agent
    db=SqliteDb(db_file="agno.db"),
    # Add the Agno MCP server to the Agent
    tools=[MCPTools(transport="streamable-http", url="https://docs.agno.com/mcp")],
    # Add the previous session history to the context
    add_history_to_context=True,
    markdown=True,
)


# ************* Create AgentOS *************
agent_os = AgentOS(agents=[agno_agent])
# Get the FastAPI app for the AgentOS
app = agent_os.get_app()

# ************* Run AgentOS *************
if __name__ == "__main__":
    agent_os.serve(app="agno_agent:app", reload=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/lectures/HomeWork/.venv/lib/python3.13/site-packages/agno/utils/models/claude.py:10
#       9 try:
# ---> 10     from anthropic.types import (
#      11         TextBlock,
#      12         ToolUseBlock,
#      13     )
#      14 except ImportError:
#
# ModuleNotFoundError: No module named 'anthropic'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 from agno.agent import Agent
#       2 from agno.db.sqlite import SqliteDb
# ----> 3 from agno.models.anthropic import Claude
#       4 from agno.os import AgentOS
#       5 from agno.tools.mcp import MCPTools
#
# File ~/Documents/lectures/HomeWork/.venv/lib/python3.13/site-packages/agno/models/anthropic/__init__.py:1
# ----> 1 from agno.models.anthropic.claude import Claude
#       3 __all__ = [
#       4     "Claude",
#       5 ]
#
# File ~/Documents/lectures/HomeWork/.venv/lib/python3.13/site-packages/agno/models/anthropic/claude.py:16
#      14 from agno.run.agent import RunOutput
#      15 from agno.utils.log import log_debug, log_error, log_warning
# ---> 16 from agno.utils.models.claude import MCPServerConfiguration, format_messages, format_tools_for_model
#      18 try:
#      19     from anthropic import Anthropic as AnthropicClient
#
# File ~/Documents/lectures/HomeWork/.venv/lib/python3.13/site-packages/agno/utils/models/claude.py:15
#      10     from anthropic.types import (
#      11         TextBlock,
#      12         ToolUseBlock,
#      13     )
#      14 except ImportError:
# ---> 15     raise ImportError("`anthropic` not installed. Please install using `pip install anthropic`")
#      18 @dataclass
#      19 class MCPToolConfiguration:
#      20     enabled: bool = True
#
# ImportError: `anthropic` not installed. Please install using `pip install anthropic`
