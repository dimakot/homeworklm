# %% [markdown]
# # создать рекурсивную функцию fibonacci, которая принимает целое число N
# # и возвращает N-ное число в последовательности Фибоначчи
# # важно - у вас при больших числах (больше 20 и далее) - программа будет тупить (Это норма)

# %%
def fibonacci(N: int) -> int:
    if N <= 1:
        return N
    return fibonacci(N - 1) + fibonacci(N - 2)

print(fibonacci(20))
# Out:
# 6765
